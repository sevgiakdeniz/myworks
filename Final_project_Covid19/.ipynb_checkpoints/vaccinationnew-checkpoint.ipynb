# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import datetime
import seaborn as sns

# %%
vaccination = pd.read_csv('vaccinations.csv')

# %%
vaccination
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 76507     Zimbabwe      ZWE  2022-01-15           7432819.0
# 76508     Zimbabwe      ZWE  2022-01-16           7438485.0
# 76509     Zimbabwe      ZWE  2022-01-17           7446076.0
# 76510     Zimbabwe      ZWE  2022-01-18           7458519.0
# 76511     Zimbabwe      ZWE  2022-01-19           7472553.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                    0.0                      NaN             NaN
# 1                    NaN                      NaN             NaN
# ...

# %%
vaccination.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76512 entries, 0 to 76511
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             76512 non-null  object
#  1   iso_code                             76512 non-null  object
#  2   date                                 76512 non-null  object
#  3   total_vaccinations                   42157 non-null  float64
#  4   people_vaccinated                    40355 non-null  float64
#  5   people_fully_vaccinated              37407 non-null  float64
#  6   total_boosters                       13897 non-null  float64
#  7   daily_vaccinations_raw               35224 non-null  float64
#  8   daily_vaccinations                   76137 non-null  float64
#  9   total_vaccinations_per_hundred       42157 non-null  float64
#  10  people_vaccinated_per_hundred        40355 non-null  float64
# ...

# %%
vaccination['date'] = pd.datetime(vaccination['date'])
# Out:
# <ipython-input-28-db5c6713cb8f>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   vaccination['date'] = pd.datetime(vaccination['date'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-db5c6713cb8f> in <module>
# ----> 1 vaccination['date'] = pd.datetime(vaccination['date'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>
