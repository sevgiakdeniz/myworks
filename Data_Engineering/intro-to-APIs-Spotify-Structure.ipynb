# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
resp_json = response.json()

# %%
resp_json[:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json).head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Favor focus over features.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response
github_response = response.json()

# %%
#github_response

# %%
from IPython.display import JSON
JSON(response.json()[:5])

# %%
pd.json_normalize(github_response)
# Out:
#              id                           type  public            created_at  \
# 0   19016501910                    CreateEvent    True  2021-11-23T14:51:27Z
# 1   19016501917                      PushEvent    True  2021-11-23T14:51:27Z
# 2   19016501898              IssueCommentEvent    True  2021-11-23T14:51:27Z
# 3   19016501896                      PushEvent    True  2021-11-23T14:51:27Z
# 4   19016501946                    CreateEvent    True  2021-11-23T14:51:27Z
# 5   19016501948                    IssuesEvent    True  2021-11-23T14:51:27Z
# 6   19016501881                     WatchEvent    True  2021-11-23T14:51:27Z
# 7   19016501882                    CreateEvent    True  2021-11-23T14:51:27Z
# 8   19016501897                    CreateEvent    True  2021-11-23T14:51:27Z
# 9   19016501838                      PushEvent    True  2021-11-23T14:51:27Z
# 10  19016501837                      PushEvent    True  2021-11-23T14:51:27Z
# 11  19016501828                      PushEvent    True  2021-11-23T14:51:27Z
# 12  19016501842                      PushEvent    True  2021-11-23T14:51:27Z
# 13  19016501822                      PushEvent    True  2021-11-23T14:51:27Z
# 14  19016501868               PullRequestEvent    True  2021-11-23T14:51:27Z
# 15  19016501839                      PushEvent    True  2021-11-23T14:51:27Z
# 16  19016501814                      PushEvent    True  2021-11-23T14:51:27Z
# 17  19016501845                      PushEvent    True  2021-11-23T14:51:27Z
# 18  19016501831                      PushEvent    True  2021-11-23T14:51:27Z
# 19  19016501844                      PushEvent    True  2021-11-23T14:51:27Z
# 20  19016501851              IssueCommentEvent    True  2021-11-23T14:51:27Z
# 21  19016501816                    MemberEvent    True  2021-11-23T14:51:27Z
# 22  19016501780  PullRequestReviewCommentEvent    True  2021-11-22T21:08:35Z
# 23  19016501811                     WatchEvent    True  2021-11-23T14:51:27Z
# 24  19016501764                      PushEvent    True  2021-11-23T14:51:27Z
# 25  19016501784                      PushEvent    True  2021-11-23T14:51:27Z
# 26  19016501820                    CreateEvent    True  2021-11-23T14:51:27Z
# 27  19016501788  PullRequestReviewCommentEvent    True  2021-11-22T14:52:22Z
# 28  19016501787  PullRequestReviewCommentEvent    True  2021-11-22T20:32:54Z
# 29  19016501721                      PushEvent    True  2021-11-23T14:51:27Z
#
#     actor.id           actor.login   actor.display_login actor.gravatar_id  \
# 0   62295960         tushar-chavan         tushar-chavan
# 1   48125859           ca-scribner           ca-scribner
# 2   20913805           HtheChemist           HtheChemist
# 3   60808802           Shinyzenith           Shinyzenith
# 4   81189305            hakanstern            hakanstern
# 5    4752614               grossmj               grossmj
# 6   39943199            MasatakaYm            MasatakaYm
# 7   92479627             KylerBest             KylerBest
# 8   67123827        Haseebullah010        Haseebullah010
# 9   41898282   github-actions[bot]        github-actions
# 10  28259639        TheoRudkiewicz        TheoRudkiewicz
# 11   6545556  andrewpearce-digital  andrewpearce-digital
# 12   5732000            NWRichmond            NWRichmond
# 13  84156115             roblefort             roblefort
# 14  39814207             pull[bot]                  pull
# 15    227836         TorsteinHonsi         TorsteinHonsi
# 16  56308637           CyrilLagger           CyrilLagger
# 17  41898282   github-actions[bot]        github-actions
# 18  92907907                  znyt                  znyt
# 19  41898282   github-actions[bot]        github-actions
# 20    793041                OndraM                OndraM
# 21  79919722               IDunion               IDunion
# 22  42787252           agustinsuso           agustinsuso
# 23  16910869                B1GLEE                B1GLEE
# 24     26967             spytheman             spytheman
# 25  89475052                cfwahl                cfwahl
# 26  94915998            Skaniskhan            Skaniskhan
# 27  42787252           agustinsuso           agustinsuso
# 28  42787252           agustinsuso           agustinsuso
# 29   1310766           theimpostor           theimpostor
#
#                                             actor.url  \
# 0          https://api.github.com/users/tushar-chavan
# 1            https://api.github.com/users/ca-scribner
# 2            https://api.github.com/users/HtheChemist
# 3            https://api.github.com/users/Shinyzenith
# 4             https://api.github.com/users/hakanstern
# 5                https://api.github.com/users/grossmj
# 6             https://api.github.com/users/MasatakaYm
# 7              https://api.github.com/users/KylerBest
# 8         https://api.github.com/users/Haseebullah010
# 9    https://api.github.com/users/github-actions[bot]
# 10        https://api.github.com/users/TheoRudkiewicz
# 11  https://api.github.com/users/andrewpearce-digital
# 12            https://api.github.com/users/NWRichmond
# 13             https://api.github.com/users/roblefort
# 14             https://api.github.com/users/pull[bot]
# 15         https://api.github.com/users/TorsteinHonsi
# 16           https://api.github.com/users/CyrilLagger
# 17   https://api.github.com/users/github-actions[bot]
# 18                  https://api.github.com/users/znyt
# 19   https://api.github.com/users/github-actions[bot]
# 20                https://api.github.com/users/OndraM
# 21               https://api.github.com/users/IDunion
# 22           https://api.github.com/users/agustinsuso
# 23                https://api.github.com/users/B1GLEE
# 24             https://api.github.com/users/spytheman
# 25                https://api.github.com/users/cfwahl
# 26            https://api.github.com/users/Skaniskhan
# 27           https://api.github.com/users/agustinsuso
# 28           https://api.github.com/users/agustinsuso
# 29           https://api.github.com/users/theimpostor
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/62295960?  ...
# 1   https://avatars.githubusercontent.com/u/48125859?  ...
# 2   https://avatars.githubusercontent.com/u/20913805?  ...
# 3   https://avatars.githubusercontent.com/u/60808802?  ...
# 4   https://avatars.githubusercontent.com/u/81189305?  ...
# 5    https://avatars.githubusercontent.com/u/4752614?  ...
# 6   https://avatars.githubusercontent.com/u/39943199?  ...
# 7   https://avatars.githubusercontent.com/u/92479627?  ...
# 8   https://avatars.githubusercontent.com/u/67123827?  ...
# 9   https://avatars.githubusercontent.com/u/41898282?  ...
# 10  https://avatars.githubusercontent.com/u/28259639?  ...
# 11   https://avatars.githubusercontent.com/u/6545556?  ...
# 12   https://avatars.githubusercontent.com/u/5732000?  ...
# 13  https://avatars.githubusercontent.com/u/84156115?  ...
# 14  https://avatars.githubusercontent.com/u/39814207?  ...
# 15    https://avatars.githubusercontent.com/u/227836?  ...
# 16  https://avatars.githubusercontent.com/u/56308637?  ...
# 17  https://avatars.githubusercontent.com/u/41898282?  ...
# 18  https://avatars.githubusercontent.com/u/92907907?  ...
# 19  https://avatars.githubusercontent.com/u/41898282?  ...
# 20    https://avatars.githubusercontent.com/u/793041?  ...
# 21  https://avatars.githubusercontent.com/u/79919722?  ...
# 22  https://avatars.githubusercontent.com/u/42787252?  ...
# 23  https://avatars.githubusercontent.com/u/16910869?  ...
# 24     https://avatars.githubusercontent.com/u/26967?  ...
# 25  https://avatars.githubusercontent.com/u/89475052?  ...
# 26  https://avatars.githubusercontent.com/u/94915998?  ...
# 27  https://avatars.githubusercontent.com/u/42787252?  ...
# 28  https://avatars.githubusercontent.com/u/42787252?  ...
# 29   https://avatars.githubusercontent.com/u/1310766?  ...
#
#                      payload.comment._links.html.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://github.com/proyecto-cema/cema-ui/pull/...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://github.com/proyecto-cema/cema-ui/pull/...
# 28  https://github.com/proyecto-cema/cema-ui/pull/...
# 29                                                NaN
#
#              payload.comment._links.pull_request.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  https://api.github.com/repos/proyecto-cema/cem...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://api.github.com/repos/proyecto-cema/cem...
# 28  https://api.github.com/repos/proyecto-cema/cem...
# 29                                                NaN
#
#    payload.comment.start_line payload.comment.original_start_line  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# 5                         NaN                                 NaN
# 6                         NaN                                 NaN
# 7                         NaN                                 NaN
# 8                         NaN                                 NaN
# 9                         NaN                                 NaN
# 10                        NaN                                 NaN
# 11                        NaN                                 NaN
# 12                        NaN                                 NaN
# 13                        NaN                                 NaN
# 14                        NaN                                 NaN
# 15                        NaN                                 NaN
# 16                        NaN                                 NaN
# 17                        NaN                                 NaN
# 18                        NaN                                 NaN
# 19                        NaN                                 NaN
# 20                        NaN                                 NaN
# 21                        NaN                                 NaN
# 22                        NaN                                 NaN
# 23                        NaN                                 NaN
# 24                        NaN                                 NaN
# 25                        NaN                                 NaN
# 26                        NaN                                 NaN
# 27                        NaN                                 NaN
# 28                        NaN                                 NaN
# 29                        NaN                                 NaN
#
#    payload.comment.start_side payload.comment.line  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# 5                         NaN                  NaN
# 6                         NaN                  NaN
# 7                         NaN                  NaN
# 8                         NaN                  NaN
# 9                         NaN                  NaN
# 10                        NaN                  NaN
# 11                        NaN                  NaN
# 12                        NaN                  NaN
# 13                        NaN                  NaN
# 14                        NaN                  NaN
# 15                        NaN                  NaN
# 16                        NaN                  NaN
# 17                        NaN                  NaN
# 18                        NaN                  NaN
# 19                        NaN                  NaN
# 20                        NaN                  NaN
# 21                        NaN                  NaN
# 22                        NaN                 77.0
# 23                        NaN                  NaN
# 24                        NaN                  NaN
# 25                        NaN                  NaN
# 26                        NaN                  NaN
# 27                        NaN                113.0
# 28                        NaN                 22.0
# 29                        NaN                  NaN
#
#    payload.comment.original_line payload.comment.side  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# 5                            NaN                  NaN
# 6                            NaN                  NaN
# 7                            NaN                  NaN
# 8                            NaN                  NaN
# 9                            NaN                  NaN
# 10                           NaN                  NaN
# 11                           NaN                  NaN
# 12                           NaN                  NaN
# 13                           NaN                  NaN
# 14                           NaN                  NaN
# 15                           NaN                  NaN
# 16                           NaN                  NaN
# 17                           NaN                  NaN
# 18                           NaN                  NaN
# 19                           NaN                  NaN
# 20                           NaN                  NaN
# 21                           NaN                  NaN
# 22                          77.0                RIGHT
# 23                           NaN                  NaN
# 24                           NaN                  NaN
# 25                           NaN                  NaN
# 26                           NaN                  NaN
# 27                         113.0                RIGHT
# 28                          22.0                RIGHT
# 29                           NaN                  NaN
#
#     payload.pull_request.head.repo.license  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
#
#     payload.pull_request.base.repo.license
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
#
# [30 rows x 508 columns]

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'Shinyzenith'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    login.append(github_response[i]["actor"]["login"])
    
for i in range(len(github_response)):
    repo.append(github_response[i]["repo"]["name"])
    
for i in range(len(github_response)):
    event_type.append(github_response[i]["type"])

# %%
for resp in github_response:
    login = resp["actor"]["login"]
    repo_name = resp["repo"]["name"]
    event_type = resp["type"]
    print(login, ' - ', repo_name, ' - ', event_type,'\n')
# Out:
# tushar-chavan  -  tushar-chavan/twAssignment  -  CreateEvent
#
# ca-scribner  -  canonical/metacontroller-operator  -  PushEvent
#
# HtheChemist  -  python-openxml/python-docx  -  IssueCommentEvent
#
# Shinyzenith  -  Shinyzenith/.dotfiles  -  PushEvent
#
# hakanstern  -  IDunion/interoperability  -  CreateEvent
#
# grossmj  -  CabbageDevelopment/qasync  -  IssuesEvent
#
# MasatakaYm  -  rougier/scientific-visualization-book  -  WatchEvent
#
# KylerBest  -  KylerBest/phase-1-context-lab  -  CreateEvent
#
# Haseebullah010  -  Haseebullah010/allparking  -  CreateEvent
#
# github-actions[bot]  -  MarlonLuan/jhipster-auto  -  PushEvent
#
# TheoRudkiewicz  -  sofamaniac/algebre_tropicale  -  PushEvent
#
# andrewpearce-digital  -  ministryofjustice/opg-use-an-lpa  -  PushEvent
#
# NWRichmond  -  getnacelle/nacelle-js  -  PushEvent
#
# roblefort  -  Legends-Mkt/docker_testnegative  -  PushEvent
#
# pull[bot]  -  amrezzd/godot  -  PullRequestEvent
#
# TorsteinHonsi  -  highcharts/highcharts  -  PushEvent
#
# CyrilLagger  -  CyrilLagger/scDiffCom  -  PushEvent
#
# github-actions[bot]  -  SPOVotes/metadata  -  PushEvent
#
# znyt  -  znyt/oss3  -  PushEvent
#
# github-actions[bot]  -  dougBelcher/usgs-scraper  -  PushEvent
#
# OndraM  -  lmc-eu/cookie-consent-manager  -  IssueCommentEvent
#
# IDunion  -  IDunion/interoperability  -  MemberEvent
#
# agustinsuso  -  proyecto-cema/cema-ui  -  PullRequestReviewCommentEvent
#
# B1GLEE  -  laukeng/snapdrop  -  WatchEvent
#
# spytheman  -  vlang/v  -  PushEvent
#
# cfwahl  -  cfwahl/public-proj_topeka_shiner_occurance  -  PushEvent
#
# Skaniskhan  -  Skaniskhan/Skaniskhan  -  CreateEvent
#
# agustinsuso  -  proyecto-cema/cema-ui  -  PullRequestReviewCommentEvent
#
# agustinsuso  -  proyecto-cema/cema-ui  -  PullRequestReviewCommentEvent
#
# theimpostor  -  praytime/praytime.app  -  PushEvent

# %%
temp = []

for element in github_response:
    print(element['type'])
    temp.append(element['type'])
# Out:
# CreateEvent
# PushEvent
# IssueCommentEvent
# PushEvent
# CreateEvent
# IssuesEvent
# WatchEvent
# CreateEvent
# CreateEvent
# PushEvent
# PushEvent
# PushEvent
# PushEvent
# PushEvent
# PullRequestEvent
# PushEvent
# PushEvent
# PushEvent
# PushEvent
# PushEvent
# IssueCommentEvent
# MemberEvent
# PullRequestReviewCommentEvent
# WatchEvent
# PushEvent
# PushEvent
# CreateEvent
# PullRequestReviewCommentEvent
# PullRequestReviewCommentEvent
# PushEvent

# %%
[element['type'] for element in github_response]
# Out:
# ['CreateEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'CreateEvent',
#  'IssuesEvent',
#  'WatchEvent',
#  'CreateEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'MemberEvent',
#  'PullRequestReviewCommentEvent',
#  'WatchEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PullRequestReviewCommentEvent',
#  'PullRequestReviewCommentEvent',
#  'PushEvent']

# %%
temp
# Out:
# ['CreateEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'CreateEvent',
#  'IssuesEvent',
#  'WatchEvent',
#  'CreateEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'MemberEvent',
#  'PullRequestReviewCommentEvent',
#  'WatchEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PullRequestReviewCommentEvent',
#  'PullRequestReviewCommentEvent',
#  'PushEvent']

# %%
# turn it into a pandas dataframe
pd.DataFrame(github_response).head()
# Out:
#             id               type  \
# 0  19016501910        CreateEvent
# 1  19016501917          PushEvent
# 2  19016501898  IssueCommentEvent
# 3  19016501896          PushEvent
# 4  19016501946        CreateEvent
#
#                                                actor  \
# 0  {'id': 62295960, 'login': 'tushar-chavan', 'di...
# 1  {'id': 48125859, 'login': 'ca-scribner', 'disp...
# 2  {'id': 20913805, 'login': 'HtheChemist', 'disp...
# 3  {'id': 60808802, 'login': 'Shinyzenith', 'disp...
# 4  {'id': 81189305, 'login': 'hakanstern', 'displ...
#
#                                                 repo  \
# 0  {'id': 431140174, 'name': 'tushar-chavan/twAss...
# 1  {'id': 408956916, 'name': 'canonical/metacontr...
# 2  {'id': 13592924, 'name': 'python-openxml/pytho...
# 3  {'id': 422541525, 'name': 'Shinyzenith/.dotfil...
# 4  {'id': 431140172, 'name': 'IDunion/interoperab...
#
#                                              payload  public  \
# 0  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 1  {'push_id': 8454261701, 'size': 1, 'distinct_s...    True
# 2  {'action': 'created', 'issue': {'url': 'https:...    True
# 3  {'push_id': 8454261689, 'size': 1, 'distinct_s...    True
# 4  {'ref': None, 'ref_type': 'repository', 'maste...    True
#
#              created_at                                                org
# 0  2021-11-23T14:51:27Z                                                NaN
# 1  2021-11-23T14:51:27Z  {'id': 53057619, 'login': 'canonical', 'gravat...
# 2  2021-11-23T14:51:27Z  {'id': 3403760, 'login': 'python-openxml', 'gr...
# 3  2021-11-23T14:51:27Z                                                NaN
# 4  2021-11-23T14:51:27Z  {'id': 79919722, 'login': 'IDunion', 'gravatar...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(github_response).head()
# Out:
#             id               type  public            created_at  actor.id  \
# 0  19016501910        CreateEvent    True  2021-11-23T14:51:27Z  62295960
# 1  19016501917          PushEvent    True  2021-11-23T14:51:27Z  48125859
# 2  19016501898  IssueCommentEvent    True  2021-11-23T14:51:27Z  20913805
# 3  19016501896          PushEvent    True  2021-11-23T14:51:27Z  60808802
# 4  19016501946        CreateEvent    True  2021-11-23T14:51:27Z  81189305
#
#      actor.login actor.display_login actor.gravatar_id  \
# 0  tushar-chavan       tushar-chavan
# 1    ca-scribner         ca-scribner
# 2    HtheChemist         HtheChemist
# 3    Shinyzenith         Shinyzenith
# 4     hakanstern          hakanstern
#
#                                     actor.url  \
# 0  https://api.github.com/users/tushar-chavan
# 1    https://api.github.com/users/ca-scribner
# 2    https://api.github.com/users/HtheChemist
# 3    https://api.github.com/users/Shinyzenith
# 4     https://api.github.com/users/hakanstern
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/62295960?  ...
# 1  https://avatars.githubusercontent.com/u/48125859?  ...
# 2  https://avatars.githubusercontent.com/u/20913805?  ...
# 3  https://avatars.githubusercontent.com/u/60808802?  ...
# 4  https://avatars.githubusercontent.com/u/81189305?  ...
#
#    payload.comment._links.html.href payload.comment._links.pull_request.href  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#   payload.comment.start_line payload.comment.original_start_line  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN
#
#   payload.comment.start_side payload.comment.line  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
#
#   payload.comment.original_line payload.comment.side  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#    payload.pull_request.head.repo.license  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    payload.pull_request.base.repo.license
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 508 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'timestamp': 1637679401,
#  'message': 'success',
#  'iss_position': {'longitude': '160.8845', 'latitude': '8.1508'}}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
    client_id="5b3311d52b2845cf9c3bf804ea93a3d2",
    client_secret="7cfe8f28ffbc4b66afe9ea86a10e5cbf"
    ))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %%
tarkan = sp.search(q="Tarkan", limit=10)

# %%
#JSON(tarkan)

# %%
list_of_uri = []
list_of_song_names = []


for element in tarkan['tracks']['items']:
    list_of_uri.append(element['uri'])
    list_of_song_names.append(element['name'])

# %%
print(list_of_song_names)
# Out:
# ['Şımarık', 'Yolla', 'Kuzu Kuzu', 'Ölürüm Sana', 'Dudu', 'İnci Tanem', 'Get Better - Gon Haziri Remix', 'Kedi Gibi', 'Kır Zincirleri', 'Tarzan Boy']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
#results

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'I Look to You',
#  'Higher Love',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found
query = "Despacito"

despacito = sp.search(q = query, limit = 50)

# %%
despacito_artists = set()

for item in despacito["tracks"]["items"]:
    for artist in item["artists"]:
        despacito_artists.add(artist["uri"])

# %%
despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
#my_playlist

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:3d9DChrdc6BOeFsbrZ3Is0")
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %%
#function building
def get_audio_feat_song(song_name):
    result = sp.search(q=song_name, limit=1)
    uri = result["tracks"]["items"][0]["uri"]
    return sp.audio_features(uri)

# %%
print(get_audio_feat_song('kuzu kuzu'))
# Out:
# [{'danceability': 0.705, 'energy': 0.883, 'key': 4, 'loudness': -8.351, 'mode': 0, 'speechiness': 0.0508, 'acousticness': 0.0223, 'instrumentalness': 0.00834, 'liveness': 0.0526, 'valence': 0.73, 'tempo': 93.909, 'type': 'audio_features', 'id': '3ajYmPDtB3P7JTPQ64Dr7P', 'uri': 'spotify:track:3ajYmPDtB3P7JTPQ64Dr7P', 'track_href': 'https://api.spotify.com/v1/tracks/3ajYmPDtB3P7JTPQ64Dr7P', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ajYmPDtB3P7JTPQ64Dr7P', 'duration_ms': 233639, 'time_signature': 4}]

# %%
song_name = "Sailing to Philadelphia"

#result =
JSON(sp.search(q=song_name, limit=1))

# %%
uri = result["tracks"]["items"][0]["uri"]
sp.audio_features(uri)
# Out:
# [{'danceability': 0.709,
#   'energy': 0.824,
#   'key': 1,
#   'loudness': -8.824,
#   'mode': 1,
#   'speechiness': 0.0453,
#   'acousticness': 0.207,
#   'instrumentalness': 0.000307,
#   'liveness': 0.0888,
#   'valence': 0.867,
#   'tempo': 118.818,
#   'type': 'audio_features',
#   'id': '2tUBqZG2AbRi7Q0BIrVrEj',
#   'uri': 'spotify:track:2tUBqZG2AbRi7Q0BIrVrEj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tUBqZG2AbRi7Q0BIrVrEj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tUBqZG2AbRi7Q0BIrVrEj',
#   'duration_ms': 291293,
#   'time_signature': 4}]

# %%
get_audio_feat_song("Sailing to Philadelphia")
# Out:
# [{'danceability': 0.589,
#   'energy': 0.484,
#   'key': 6,
#   'loudness': -10.126,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.641,
#   'instrumentalness': 0.107,
#   'liveness': 0.0873,
#   'valence': 0.149,
#   'tempo': 99.067,
#   'type': 'audio_features',
#   'id': '4eA4i2Uf0DDIkpyesj98Ag',
#   'uri': 'spotify:track:4eA4i2Uf0DDIkpyesj98Ag',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eA4i2Uf0DDIkpyesj98Ag',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eA4i2Uf0DDIkpyesj98Ag',
#   'duration_ms': 353120,
#   'time_signature': 4}]

# %%
result.keys()
# Out:
# dict_keys(['tracks'])

# %%
result["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2tUBqZG2AbRi7Q0BIrVrEj'

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
playlists = ["https://open.spotify.com/playlist/0ce6Rmxf7QXroqa1wzjWY8?si=05b8e416dedd4894",
             "https://open.spotify.com/playlist/2PjVPkj4a9kBvQIXaZ6UUt?si=c83fe4d8a4974095",
             "https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=549db4d4f4ca4c18",
             "https://open.spotify.com/playlist/37i9dQZF1DX7Mq3mO5SSDc?si=55c443251302424e"
            ]

# %%
results = []

# option 1
for p in playlists:
    results.append(sp.playlist_tracks(p))

# option 2
results = [sp.playlist_tracks(p) for p in playlists]

# %%
len(results)
# Out:
# 4

# %%
JSON(results[0]["items"])

# %%
len(results)
# Out:
# 4

# %%
uris = []
names = []
# option 1
for result in results:
    for i in result["items"]:
        uris.append(i["track"]["uri"])
        names.append(i["track"]["name"])

# %%
# option 2 (problem: lists nested inside the list)
# [[i["track"]["uri"] for i in result["items"]] for result in results]
# [[i["track"]["name"] for i in result["items"]] for result in results]

# %%
audio_feat = []

for uri in uris:
    audio_feat.extend(sp.audio_features(uri))
# audio_feat

# %%
audio_featt[0]
# Out:
# {'danceability': 0.535,
#  'energy': 0.724,
#  'key': 5,
#  'loudness': -9.905,
#  'mode': 1,
#  'speechiness': 0.0618,
#  'acousticness': 0.202,
#  'instrumentalness': 0.901,
#  'liveness': 0.0983,
#  'valence': 0.37,
#  'tempo': 159.948,
#  'type': 'audio_features',
#  'id': '5Tnx4R7Gwj1LZsfssfzchh',
#  'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh',
#  'track_href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Tnx4R7Gwj1LZsfssfzchh',
#  'duration_ms': 167987,
#  'time_signature': 4}

# %%
audiofeat_df = pd.DataFrame(audio_feat)
# audiofeat_df

# %%
audiofeat_df["name"] = names
# audiofeat_df

# %%
cols = audiofeat_df.columns.to_list()
# cols

# %%
cols = cols[-1:] + cols[:-1]

# %%
audiofeat_df = audiofeat_df[cols]
audiofeat_df.head()
# Out:
#                                      name  danceability  energy  key  \
# 0  You're the One - From "I Lost My Body"         0.535   0.724    5
# 1                               The Alien         0.464   0.334    6
# 2             Oh, Pecador (Oh, Sinne Man)         0.623   0.239   11
# 3                 Moon (And It Went Like)         0.662   0.657    7
# 4                         Never Come Back         0.776   0.684    5
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.905     1       0.0618         0.202          0.901000    0.0983
# 1   -12.916     1       0.0313         0.307          0.247000    0.1100
# 2   -12.638     0       0.0979         0.886          0.000929    0.1710
# 3   -10.002     1       0.0345         0.288          0.856000    0.1020
# 4    -8.934     1       0.0367         0.405          0.559000    0.0663
#
#    valence    tempo            type                      id  \
# 0   0.3700  159.948  audio_features  5Tnx4R7Gwj1LZsfssfzchh
# 1   0.3260  165.278  audio_features  5eKfpH2dQ7FltCqb7LWEGJ
# 2   0.5850  124.485  audio_features  0R3OcHrzq3f8raukyZgTAc
# 3   0.0584  117.986  audio_features  24upABZ8A0sAepfu91sEYr
# 4   0.6550  127.979  audio_features  7IBrKDuBlyz3vW9JFCux10
#
#                                     uri  \
# 0  spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 1  spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 2  spotify:track:0R3OcHrzq3f8raukyZgTAc
# 3  spotify:track:24upABZ8A0sAepfu91sEYr
# 4  spotify:track:7IBrKDuBlyz3vW9JFCux10
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1L...
# 1  https://api.spotify.com/v1/tracks/5eKfpH2dQ7Fl...
# 2  https://api.spotify.com/v1/tracks/0R3OcHrzq3f8...
# 3  https://api.spotify.com/v1/tracks/24upABZ8A0sA...
# 4  https://api.spotify.com/v1/tracks/7IBrKDuBlyz3...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Tnx...       167987
# 1  https://api.spotify.com/v1/audio-analysis/5eKf...       328933
# 2  https://api.spotify.com/v1/audio-analysis/0R3O...       145773
# 3  https://api.spotify.com/v1/audio-analysis/24up...       390639
# 4  https://api.spotify.com/v1/audio-analysis/7IBr...       305480
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
playlists = ["https://open.spotify.com/playlist/0ce6Rmxf7QXroqa1wzjWY8?si=05b8e416dedd4894",
             "https://open.spotify.com/playlist/2PjVPkj4a9kBvQIXaZ6UUt?si=c83fe4d8a4974095",
             "https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=549db4d4f4ca4c18",
             "https://open.spotify.com/playlist/37i9dQZF1DX7Mq3mO5SSDc?si=55c443251302424e"
            ]

# %%
def get_tracks_info(url): 
    playlist_tracks = sp.playlist_tracks(url)
    
    track_uri = [track['track']['uri'] for track in playlist_tracks['items']]
    track_name = [track['track']['name'] for track in playlist_tracks['items']]
    
    return pd.DataFrame({
        'uri':track_uri,
        'name':track_name
    })

playlists_songs = [get_tracks_info(playlist_url) for playlist_url in playlists]

playlist_df = pd.concat(playlists_songs, axis=0)

audio_features = [sp.audio_features(uri)[0] for uri in playlist_df['uri']]

pd.concat([playlist_df.reset_index(drop=True), pd.DataFrame(audio_features).reset_index(drop=True)],
          axis=1, ignore_index=True)
# Out:
#                                        0   \
# 0    spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 1    spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 2    spotify:track:0R3OcHrzq3f8raukyZgTAc
# 3    spotify:track:24upABZ8A0sAepfu91sEYr
# 4    spotify:track:7IBrKDuBlyz3vW9JFCux10
# ..                                    ...
# 234  spotify:track:1xZdjsAGrY4BUIbIlYy3EX
# 235  spotify:track:7aRGb3vZGMLNpK2PEdUjdA
# 236  spotify:track:4F4neui0edP1ozygvFiCi7
# 237  spotify:track:2tY1gxCKslfXLFpFofYmJQ
# 238  spotify:track:5Tl0HJvynZtKdSUMKbFVVX
#
#                                          1      2      3   4       5   6   \
# 0    You're the One - From "I Lost My Body"  0.535  0.724   5  -9.905   1
# 1                                 The Alien  0.464  0.334   6 -12.916   1
# 2               Oh, Pecador (Oh, Sinne Man)  0.623  0.239  11 -12.638   0
# 3                   Moon (And It Went Like)  0.662  0.657   7 -10.002   1
# 4                           Never Come Back  0.776  0.684   5  -8.934   1
# ..                                      ...    ...    ...  ..     ...  ..
# 234                       Strictly Business  0.712  0.895  10  -4.212   0
# 235                             He Got Game  0.825  0.639   4  -6.607   1
# 236                          Rock The Bells  0.896  0.517   6 -12.813   0
# 237                            Brass Monkey  0.914  0.586   6  -8.435   0
# 238         Hard Knock Life (Ghetto Anthem)  0.884  0.679  10  -5.857   0
#
#          7        8         9       10      11       12              13  \
# 0    0.0618  0.20200  0.901000  0.0983  0.3700  159.948  audio_features
# 1    0.0313  0.30700  0.247000  0.1100  0.3260  165.278  audio_features
# 2    0.0979  0.88600  0.000929  0.1710  0.5850  124.485  audio_features
# 3    0.0345  0.28800  0.856000  0.1020  0.0584  117.986  audio_features
# 4    0.0367  0.40500  0.559000  0.0663  0.6550  127.979  audio_features
# ..      ...      ...       ...     ...     ...      ...             ...
# 234  0.2540  0.18100  0.000018  0.1080  0.7270   96.338  audio_features
# 235  0.1850  0.07310  0.022500  0.0612  0.8660   97.389  audio_features
# 236  0.1430  0.00596  0.364000  0.1240  0.2850   98.472  audio_features
# 237  0.3300  0.00203  0.000002  0.0992  0.6550  116.371  audio_features
# 238  0.2820  0.09570  0.002090  0.0289  0.5910   76.993  audio_features
#
#                          14                                    15  \
# 0    5Tnx4R7Gwj1LZsfssfzchh  spotify:track:5Tnx4R7Gwj1LZsfssfzchh
# 1    5eKfpH2dQ7FltCqb7LWEGJ  spotify:track:5eKfpH2dQ7FltCqb7LWEGJ
# 2    0R3OcHrzq3f8raukyZgTAc  spotify:track:0R3OcHrzq3f8raukyZgTAc
# 3    24upABZ8A0sAepfu91sEYr  spotify:track:24upABZ8A0sAepfu91sEYr
# 4    7IBrKDuBlyz3vW9JFCux10  spotify:track:7IBrKDuBlyz3vW9JFCux10
# ..                      ...                                   ...
# 234  1xZdjsAGrY4BUIbIlYy3EX  spotify:track:1xZdjsAGrY4BUIbIlYy3EX
# 235  7aRGb3vZGMLNpK2PEdUjdA  spotify:track:7aRGb3vZGMLNpK2PEdUjdA
# 236  4F4neui0edP1ozygvFiCi7  spotify:track:4F4neui0edP1ozygvFiCi7
# 237  2tY1gxCKslfXLFpFofYmJQ  spotify:track:2tY1gxCKslfXLFpFofYmJQ
# 238  5Tl0HJvynZtKdSUMKbFVVX  spotify:track:5Tl0HJvynZtKdSUMKbFVVX
#
#                                                     16  \
# 0    https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1L...
# 1    https://api.spotify.com/v1/tracks/5eKfpH2dQ7Fl...
# 2    https://api.spotify.com/v1/tracks/0R3OcHrzq3f8...
# 3    https://api.spotify.com/v1/tracks/24upABZ8A0sA...
# 4    https://api.spotify.com/v1/tracks/7IBrKDuBlyz3...
# ..                                                 ...
# 234  https://api.spotify.com/v1/tracks/1xZdjsAGrY4B...
# 235  https://api.spotify.com/v1/tracks/7aRGb3vZGMLN...
# 236  https://api.spotify.com/v1/tracks/4F4neui0edP1...
# 237  https://api.spotify.com/v1/tracks/2tY1gxCKslfX...
# 238  https://api.spotify.com/v1/tracks/5Tl0HJvynZtK...
#
#                                                     17      18  19
# 0    https://api.spotify.com/v1/audio-analysis/5Tnx...  167987   4
# 1    https://api.spotify.com/v1/audio-analysis/5eKf...  328933   4
# 2    https://api.spotify.com/v1/audio-analysis/0R3O...  145773   4
# 3    https://api.spotify.com/v1/audio-analysis/24up...  390639   4
# 4    https://api.spotify.com/v1/audio-analysis/7IBr...  305480   4
# ..                                                 ...     ...  ..
# 234  https://api.spotify.com/v1/audio-analysis/1xZd...  285413   4
# 235  https://api.spotify.com/v1/audio-analysis/7aRG...  286200   4
# 236  https://api.spotify.com/v1/audio-analysis/4F4n...  240493   4
# 237  https://api.spotify.com/v1/audio-analysis/2tY1...  157440   4
# 238  https://api.spotify.com/v1/audio-analysis/5Tl0...  238467   4
#
# [239 rows x 20 columns]
