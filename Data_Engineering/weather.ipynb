# %%
# !pip install pyowm
# Out:
# Requirement already satisfied: pyowm in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: geojson<3,>=2.3.0 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from pyowm) (2.5.0)
# Requirement already satisfied: requests[socks] in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from pyowm) (2.25.1)
# Requirement already satisfied: PySocks<2,>=1.7.1 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from pyowm) (1.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]->pyowm) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]->pyowm) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]->pyowm) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sevgiakdeniz/opt/anaconda3/lib/python3.8/site-packages (from requests[socks]->pyowm) (1.26.4)

# %%
from pyowm import OWM
#from pyowm.utils import config
#from pyowm.utils import timestamps
import pandas as pd
from numpy import nan


OWM_key = "97ac65d48d96e3aa11b4062e28ab6bae"
city = "Berlin"
country = "DE"

owm = OWM(OWM_key)
mgr = owm.weather_manager()

# Will it be clear tomorrow at this time in Milan (Italy) ?
forecast = mgr.forecast_at_place(city + ',' + country, '3h')
# answer = forecast.will_be_clear_at(timestamps.tomorrow())



def forecast_extraction(forecast_object): 
    """
    Given a forecast object from Open weathor Pyhton API, 
    return a structured dataframe. 

    :param: forecast object
    :returns: a dataframe with specific weather information
    """
    forecast_df = pd.json_normalize({
        'time' : forecast_object.reference_time(timeformat='date'), 
        'temperature' : forecast_object.temperature(unit='celsius'), 
        'precipitation_probabily' : forecast_object.precipitation_probability, 
        'rain' : forecast_object.rain, 
        'humidity' : forecast_object.humidity, 
        'status' : forecast_object.status, 
        #'snow' : [nan if forecast_object.snow is None else forecast_object.snow], 
        'wind' : forecast_object.wind('km_hour')
    })

    return(forecast_df)

weather_forecast = pd.concat(
    [forecast_extraction(weather) for weather in forecast.forecast.weathers]
)

weather_forecast.head()
# Out:
#                        time  precipitation_probabily  humidity  status  \
# 0 2021-11-23 21:00:00+00:00                      0.0        89  Clouds
# 0 2021-11-24 00:00:00+00:00                      0.0        89  Clouds
# 0 2021-11-24 03:00:00+00:00                      0.0        92  Clouds
# 0 2021-11-24 06:00:00+00:00                      0.0        87  Clouds
# 0 2021-11-24 09:00:00+00:00                      0.0        80  Clouds
#
#    temperature.temp  temperature.temp_kf  temperature.temp_max  \
# 0              6.67              -272.98                  6.67
# 0              6.45              -273.00                  6.45
# 0              5.10              -273.15                  5.10
# 0              5.94              -273.15                  5.94
# 0              6.83              -273.15                  6.83
#
#    temperature.temp_min  temperature.feels_like  wind.speed  wind.deg  \
# 0                  6.50                    4.47      11.016       243
# 0                  6.30                    4.17      11.196       269
# 0                  5.10                    3.03       8.964       268
# 0                  5.94                    4.45       7.236       255
# 0                  6.83                    5.51       7.164       253
#
#    wind.gust
# 0     27.108
# 0     29.232
# 0     24.156
# 0     22.896
# 0     20.124
